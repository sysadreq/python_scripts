# %%
import os
import glob
import re

# %%
#get the current working directory
directory = os.getcwd()

#The os.path.join() function is helpful if you need to create strings for filenames
#C:\Users\Ronn\Desktop\python_scripts-master\messages.txt
file=os.path.join(directory,"messages.txt")



with open(file) as msg:
    
    for lines in msg.readlines():
        if "acct" in lines:
            for items in lines.split():
                if "=" in items:
                    var=items.split("=")
                    key=var[0]
                    value=var[1]
                    print(key,value)
# Out:
# node s4ha1prd
# type USER_START
# msg audit(1553127121.611:341421):
# pid 32519
# uid 0
# auid 2005
# ses 36336
# msg 'op
# acct "s4padm"
# exe "/usr/sbin/cron"
# hostname ?
# addr ?
# terminal cron
# res success'
# node s4ha1prd
# type CRED_REFR
# msg audit(1553127121.611:341422):
# pid 32519
# uid 0
# auid 2005
# ses 36336
# msg 'op
# acct "s4padm"
# exe "/usr/sbin/cron"
# hostname ?
# addr ?
# terminal cron
# res success'
# node s4ha1prd
# type USER_START
# msg audit(1553127121.615:341423):
# pid 32523
# uid 0
# auid 2005
# ses 36338
# msg 'op
# acct "s4padm"
# exe "/usr/sbin/cron"
# hostname ?
# addr ?
# terminal cron
# res success'
# node s4ha1prd
# type CRED_REFR
# msg audit(1553127121.615:341424):
# pid 32523
# uid 0
# auid 2005
# ses 36338
# msg 'op
# acct "s4padm"
# exe "/usr/sbin/cron"
# hostname ?
# addr ?
# terminal cron
# res success'
# node s4ha1prd
# type USER_START
# msg audit(1553127121.615:341425):
# pid 32521
# uid 0
# auid 2005
# ses 36337
# msg 'op
# ...

# %%
list1=[1,2]

# %%
len(list1)
# Out:
# 2
